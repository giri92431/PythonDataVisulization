# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.ylabel('test1')

# %%
plt.show()

# %%
print("next line ")
# Out:
# next line

# %%
import numpy as np
import matplotlib as mlp

# %%
x = np.linspace(0,5,50)
y_cos = np.cos(x)
y_sin = np.sin(x)
plt.figure() # initalize a figure
plt.plot(x,y_cos) #plot series of cordinates as a line
plt.plot(x,y_sin)
plt.xlabel('x')
plt.ylabel('y')
plt.title('title')
plt.show()

# %%
list(mlp.rcParams['axes.prop_cycle'])
# Out:
# [{'color': '#1f77b4'},
#  {'color': '#ff7f0e'},
#  {'color': '#2ca02c'},
#  {'color': '#d62728'},
#  {'color': '#9467bd'},
#  {'color': '#8c564b'},
#  {'color': '#e377c2'},
#  {'color': '#7f7f7f'},
#  {'color': '#bcbd22'},
#  {'color': '#17becf'}]
